# %%
import pandas as pd
import sql_functions as sf

# %%
schema = 'organic_africa' # UPDATE 'TABLE_SCHEMA' based on schema used in class 
engine = sf.get_engine()
    
all_farmes = {}

all_farmes['OGInfo__OGMB_1_df'] = sf.get_dataframe(f'SELECT * FROM {schema}."OGInfo__OGMB_1"')
all_farmes['OG_Info__OGOrg_1_df'] = sf.get_dataframe(f'SELECT * FROM {schema}."OG_Info__OGOrg_1"')
all_farmes['wc_info_bayoba_1_df'] = sf.get_dataframe(f'SELECT * FROM {schema}."wc_info_bayoba_1"')
all_farmes['wc_info__WCOrg_1_df'] = sf.get_dataframe(f'SELECT * FROM {schema}."wc_info__WCOrg_1"')

all_farmes['OG_Info_reserve__OGOrg_1_df'] = sf.get_dataframe(f'SELECT * FROM {schema}."OG_Info_reserve__OGOrg_1"')

# %%
all_farmes['OGInfo__OGMB_1_df'] = all_farmes['OGInfo__OGMB_1_df'][['ID', 'OG_Nr', 'OG_code', 'Production_Unit', 'Area', 'Ward_Nr/Name',
       'Species', 'Surname', 'First_names', 'Sex', 'ID_Number', 'Date_of_Birth', 'date_contracted', 'Date_dropped_out',
       'Reason_dropped_out', 'Address', 'OG_Organic_Status', 'OG_Organic_Status_from_Date', 'Fairtrade']]
all_farmes['OGInfo__OGMB_1_df'].columns = map(str.lower, all_farmes['OGInfo__OGMB_1_df'].columns)
all_farmes['OG_Info__OGOrg_1_df'] = all_farmes['OG_Info__OGOrg_1_df'][['ID', 'OG_Nr', 'OG_code', 'Production_Unit', 'Area', 'Ward_Nr/Name',
       'Species', 'Surname', 'First_names', 'Sex', 'ID_Number',
       'Date_of_Birth', 'Date_contracted', 'Date_dropped_out',
       'Reason_dropped_out', 'OG_Organic_Status', 'Address',
       'OG_Organic_Status_from_Date', 'Fairtrade','ward_nr']]
all_farmes['OG_Info__OGOrg_1_df'].columns = map(str.lower, all_farmes['OG_Info__OGOrg_1_df'].columns)
    
all_farmes['wc_info_bayoba_1_df'] = all_farmes['wc_info_bayoba_1_df'][['ID', 'WC_Nr', 'WC_code', 'Production_Unit', 'Area', 'Ward_Nr/Name',
       'Species', 'Surname', 'First_names', 'Sex', 'ID_Number', 'Date_contracted', 'Date_dropped_out',
       'Reason_dropped_out', 'Address', 'Organic_Status', 'Organic_Status_from_Date', 'Fairtrade', 'Date_of_Birth', 'ward_nr']]
all_farmes['wc_info_bayoba_1_df'].columns = map(str.lower, all_farmes['wc_info_bayoba_1_df'].columns)
    
all_farmes['wc_info__WCOrg_1_df'] = all_farmes['wc_info__WCOrg_1_df'][['ID', 'WC_Nr', 'WC_code', 'Production_Unit', 'Area', 'Ward_Nr/Name',
       'Species', 'Surname', 'First_names', 'Sex', 'ID_Number',
       'Date_contracted', 'Reason_dropped_out', 'Address', 'Organic_Status', 'Organic_Status_from_Date', 'Fairtrade', 'Date_dropped_out', 'ward_nr']]
all_farmes['wc_info__WCOrg_1_df'].columns = map(str.lower, all_farmes['wc_info__WCOrg_1_df'].columns)

all_farmes['OG_Info_reserve__OGOrg_1_df'] = all_farmes['OG_Info_reserve__OGOrg_1_df'][['ID', 'OG_Nr', 'OG_code', 'Production_Unit', 'Area', 'Ward_Nr/Name',
       'Species', 'Surname', 'First_names', 'Sex', 'ID_Number',
       'Date_of_Birth', 'Date_contracted', 'Date_dropped_out',
       'Reason_dropped_out', 'Address', 'OG_Organic_Status',
       'OG_Organic_Status_from_Date', 'Fairtrade', 'ward_nr']]
all_farmes['OG_Info_reserve__OGOrg_1_df'].columns = map(str.lower, all_farmes['OG_Info_reserve__OGOrg_1_df'].columns)

# %%
all_farmes['wc_info__WCOrg_1_df']
# Out:
#         id    wc_nr wc_code     production_unit                area  \
# 0     4942   3962.0    HWWC  Matabeleland North              Hwange
# 1     5608   3692.0    HWWC  Matabeleland North              Hwange
# 2    10630   1773.0    HWWC  Matabeleland North              Hwange
# 3     1763   1772.0    HWWC  Matabeleland North              Hwange
# 4     1766   1775.0    HWWC  Matabeleland North              Hwange
# ..     ...      ...     ...                 ...                 ...
# 560  11146   1057.0    CMWC          Manicaland  Chimanimani Rusitu
# 561  11147  21040.0    CMWC          Manicaland  Chimanimani Rusitu
# 562  11148   2555.0    CMWC          Manicaland  Chimanimani Rusitu
# 563  11149   2066.0    CMWC          Manicaland  Chimanimani Rusitu
# 564  11150   1069.0    CMWC          Manicaland  Chimanimani Rusitu
#
#      ward_nr/name         species    surname first_names     sex  \
# 0        6 Gondwa     Devils Claw       Moyo        Pios    male
# ...

# %%
# Collecting Date of Birth
all_birthdates = {}

all_birthdates['wc_insp_2013__WCOrg_df'] = sf.get_dataframe(f'SELECT * FROM {schema}."wc_insp_2013__WCOrg"')
all_birthdates['wc_insp_2014__WCOrg_df'] = sf.get_dataframe(f'SELECT * FROM {schema}."wc_insp_2014__WCOrg"')
all_birthdates['wc_insp_2015__WCOrg_df'] = sf.get_dataframe(f'SELECT * FROM {schema}."wc_insp_2015__WCOrg"')
all_birthdates['wc_insp_2016__WCOrg_df'] = sf.get_dataframe(f'SELECT * FROM {schema}."wc_insp_2016__WCOrg"')
all_birthdates['wc_insp_2017__WCOrg_df'] = sf.get_dataframe(f'SELECT * FROM {schema}."wc_insp_2017__WCOrg"')

# %%
all_birthdates['wc_insp_2013__WCOrg_df'] = allbirthdates['wc_insp_2013__WCOrg_df'][['WC_Nr', 'Date_of_birth']]
all_birthdates['wc_insp_2014__WCOrg_df'] = allbirthdates['wc_insp_2014__WCOrg_df'][['WC_Nr', 'Date_of_birth']]
all_birthdates['wc_insp_2015__WCOrg_df'] = allbirthdates['wc_insp_2015__WCOrg_df'][['WC_Nr', 'Date_of_birth']]
all_birthdates['wc_insp_2016__WCOrg_df'] = allbirthdates['wc_insp_2016__WCOrg_df'][['WC_Nr', 'Date_of_birth']]
all_birthdates['wc_insp_2017__WCOrg_df'] = allbirthdates['wc_insp_2017__WCOrg_df'][['WC_Nr', 'Date_of_birth']]

# %%
all_birthdates['wc_insp_2013__WCOrg_df'].columns = map(str.lower, all_birthdates['wc_insp_2013__WCOrg_df'].columns)
all_birthdates['wc_insp_2014__WCOrg_df'].columns = map(str.lower, all_birthdates['wc_insp_2014__WCOrg_df'].columns)
all_birthdates['wc_insp_2015__WCOrg_df'].columns = map(str.lower, all_birthdates['wc_insp_2015__WCOrg_df'].columns)
all_birthdates['wc_insp_2016__WCOrg_df'].columns = map(str.lower, all_birthdates['wc_insp_2016__WCOrg_df'].columns)
all_birthdates['wc_insp_2017__WCOrg_df'].columns = map(str.lower, all_birthdates['wc_insp_2017__WCOrg_df'].columns)

# %%
all_birthdates_df = pd.concat(all_birthdates.values())

# %%
all_birthdates_df
# Out:
#      wc_nr            date_of_birth
# 0   1775.0  1955-10-05 00:00:00.000
# 1   2901.0                     None
# 2   2902.0  1995-09-16 00:00:00.000
# 3   2903.0  1933-01-01 00:00:00.000
# 4   2904.0  1932-09-03 00:00:00.000
# ..     ...                      ...
# 5   3965.0  1974-08-05 00:00:00.000
# 6   3699.0  1957-06-01 00:00:00.000
# 7   4143.0  1963-02-02 00:00:00.000
# 8   4144.0  1972-09-01 00:00:00.000
# 9   4145.0  1962-04-04 00:00:00.000
#
# [5473 rows x 2 columns]

# %%
all_birthdates_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5473 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   wc_nr          5472 non-null   float64
#  1   date_of_birth  341 non-null    object
# dtypes: float64(1), object(1)
# memory usage: 128.3+ KB

# %%
# Counting duplicated Wc_Nr to drop them

all_birthdates_df["wc_nr"].duplicated().value_counts()
# Out:
# False    3745
# True     1728
# Name: wc_nr, dtype: int64

# %%
all_birthdates_df = all_birthdates_df.drop_duplicates(subset="wc_nr")

# %%
all_birthdates_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3745 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   wc_nr          3744 non-null   float64
#  1   date_of_birth  291 non-null    object
# dtypes: float64(1), object(1)
# memory usage: 87.8+ KB

# %%
all_birthdates_df["date_of_birth"].isnull().value_counts()

# Insgesamt 291 Geburtsdaten
# Out:
# True     3454
# False     291
# Name: date_of_birth, dtype: int64

# %%
len(list(set(all_birthdates_df["wc_nr"]) & set(all_farmes['wc_info__WCOrg_1_df'][['wc_nr']].squeeze())))
# Out:
# 453

# %%
all_farmes['wc_info__WCOrg_1_df'] = pd.merge(all_farmes['wc_info__WCOrg_1_df'], all_birthdates_df, how="left", on="wc_nr")

# %%
all_farmes['wc_info__WCOrg_1_df']
# Out:
#         id    wc_nr wc_code     production_unit                area  \
# 0     4942   3962.0    HWWC  Matabeleland North              Hwange
# 1     5608   3692.0    HWWC  Matabeleland North              Hwange
# 2    10630   1773.0    HWWC  Matabeleland North              Hwange
# 3     1763   1772.0    HWWC  Matabeleland North              Hwange
# 4     1766   1775.0    HWWC  Matabeleland North              Hwange
# ..     ...      ...     ...                 ...                 ...
# 560  11146   1057.0    CMWC          Manicaland  Chimanimani Rusitu
# 561  11147  21040.0    CMWC          Manicaland  Chimanimani Rusitu
# 562  11148   2555.0    CMWC          Manicaland  Chimanimani Rusitu
# 563  11149   2066.0    CMWC          Manicaland  Chimanimani Rusitu
# 564  11150   1069.0    CMWC          Manicaland  Chimanimani Rusitu
#
#      ward_nr/name         species    surname first_names     sex  \
# 0        6 Gondwa     Devils Claw       Moyo        Pios    male
# ...

# %%
all_farmes['OG_Info_reserve__OGOrg_1_df']
# Out:
#        id    og_nr og_code      production_unit      area ward_nr/name  \
# 0     110   3463.0    BNOG   Matabeleland North     Binga   5 Sinakoma
# 1     151   4084.0    BNOG   Matabeleland North     Binga   5 Sinakoma
# 2     152   4085.0    BNOG   Matabeleland North     Binga   5 Sinakoma
# 3     153   4088.0    BNOG   Matabeleland North     Binga   5 Sinakoma
# 4     302   5156.0    BNOG   Matabeleland North     Binga   5 Sinakoma
# ..    ...      ...     ...                  ...       ...          ...
# 790  3546  20023.0    MUOG  Mashonaland Central  Mushumbi            3
# 791  3549  20026.0    MUOG  Mashonaland Central  Mushumbi            3
# 792  3550  20027.0    MUOG  Mashonaland Central  Mushumbi            3
# 793  3551  20028.0    MUOG  Mashonaland Central  Mushumbi            3
# 794  1861  14001.0    BNOG   Matabeleland North     Binga      11 Lubu
#
#                       species  surname first_names     sex     id_number  \
# ...

# %%
all_farmes['OGInfo__OGMB_1_df'][['ward_nr']] = all_farmes['OGInfo__OGMB_1_df'][['ward_nr/name']]

# %%
all_farmes['OGInfo__OGMB_1_df'].shape
# Out:
# (8166, 20)

# %%
all_farmes['wc_info_bayoba_1_df'].shape
# Out:
# (10952, 20)

# %%
all_farmes['OG_Info_reserve__OGOrg_1_df'].shape
# Out:
# (795, 20)

# %%
all_farmes['wc_info__WCOrg_1_df'].shape
# Out:
# (565, 20)

# %%
all_farmes['OG_Info__OGOrg_1_df'].shape
# Out:
# (1403, 20)

# %%
all_farmes['OG_Info_reserve__OGOrg_1_df'][['id']].squeeze().is_unique
# Out:
# True

# %%
concated_farmers = pd.concat(all_farmes)

# %%
concated_farmers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 21881 entries, ('OGInfo__OGMB_1_df', 0) to ('OG_Info_reserve__OGOrg_1_df', 794)
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           21881 non-null  int64
#  1   og_nr                        10364 non-null  float64
#  2   og_code                      10364 non-null  object
#  3   production_unit              21881 non-null  object
#  4   area                         21881 non-null  object
#  5   ward_nr/name                 21461 non-null  object
#  6   species                      21881 non-null  object
#  7   surname                      21879 non-null  object
#  8   first_names                  21877 non-null  object
#  9   sex                          21881 non-null  object
#  10  id_number                    19837 non-null  object
#  11  date_of_birth                2883 non-null   object
# ...

# %%
concated_farmers[concated_farmers['organic_status','organic_status_from_date'] not null]
# Out:
#   Cell In[552], line 1
#     concated_farmers[concated_farmers['organic_status','organic_status_from_date'] not null]
#                                                                                        ^
# SyntaxError: invalid syntax

# %%
concated_farmers.duplicated().value_counts()
# Out:
# /var/folders/x5/v1d8l9v94679fhr8vd07ys9c0000gn/T/ipykernel_7180/627957838.py:1: FutureWarning: Comparison of Timestamp with datetime.date is deprecated in order to match the standard library behavior. In a future version these will be considered non-comparable. Use 'ts == pd.Timestamp(date)' or 'ts.date() == date' instead.
#   concated_farmers.duplicated().value_counts()
# False    21838
# True        43
# dtype: int64

# %%
concated_farmers[['og_nr']].squeeze().is_unique
# Out:
# False
